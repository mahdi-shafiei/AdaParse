# %%
import os
import json
from pathlib import Path

# %%
p = Path('/lus/flare/projects/FoundEpidem/siebenschuh/aurora_gpt/output/nougat/new_nougat_HF/parsed_pdfs/02f129db-de7a-4459-9599-e4b93eecb8c6.jsonl')

with open(p, 'r') as f:
    for line in f:
        dd = json.loads(line)
        break

# %%
dd['pages'][2]
# Out:
# {'index': 2,
#  'text': '\n\n## Introduction\n\nLifestyle [1] and pharmacotherapy interventions [2,'}
